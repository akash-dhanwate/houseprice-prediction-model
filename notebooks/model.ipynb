# %%
# import libraries

# %%
import numpy as np
import pandas as pd

# %%
# read files 
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
#check shape 
print(train.shape)
print(test.shape)
# Out:
# (1460, 81)
# (1459, 80)

# %%
#view first rows test
print(test.head())
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
#train 
print(train.head())
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
# distribution of price 
import matplotlib.pyplot as plt
plt.figure(figsize=(10 , 5))
plt.hist(train["SalePrice"] , bins=30)
plt.title('SalePrice Distribution')
plt.show()

# %%
#Target TRansformation 
y = np.log1p(train['SalePrice'])
train = train.drop('SalePrice' , axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/Cellar/jupyterlab/4.5.6_2/libexec/lib/python3.14/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
# #separate target 
# y = train['SalePrice']
# train = train.drop('SalePrice' , axis=1)

# %%
# combile train + test 
data = pd.concat([ train , test ] , axis = 0 )

# %%
# drop id that is not usefull in the data 
data = data.drop('Id' , axis = 1)

# %%
# handle missing values
data.fillna(data.median(numeric_only = True ), inplace =True)
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0             60       RL         65.0     8450   Pave   NaN      Reg
# 1             20       RL         80.0     9600   Pave   NaN      Reg
# 2             60       RL         68.0    11250   Pave   NaN      IR1
# 3             70       RL         60.0     9550   Pave   NaN      IR1
# 4             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1454         160       RM         21.0     1936   Pave   NaN      Reg
# 1455         160       RM         21.0     1894   Pave   NaN      Reg
# 1456          20       RL        160.0    20000   Pave   NaN      Reg
# 1457          85       RL         62.0    10441   Pave   NaN      Reg
# 1458          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC  Fence  \
# ...

# %%
#feature engineering 
current_yr = 2026;
data['HouseAge'] = current_yr -data['YearBuilt']
data['RemodAge'] = current_yr - data['YearRemodAdd']
data['GarageAge'] = current_yr - data['GarageYrBlt']
data['ToatalSF'] = (
    data['TotalBsmtSF'] +
    data['1stFlrSF'] +
    data['2ndFlrSF'])
data['TotalBath'] = (
    data['FullBath'] +
    0.5 * data['HalfBath'] + 
    data['BsmtFullBath']+
    0.5* data['BsmtHalfBath'])
data = data.drop(['YearBuilt' , 'YearRemodAdd' , 'GarageYrBlt'] , axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/Cellar/jupyterlab/4.5.6_2/libexec/lib/python3.14/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
# encode categorical data 
data = pd.get_dummies(data , drop_first = True)
# conver the text into numbers because model need the numbers not the texts

# %%
#split back to train / test
train_processed = data[:len(y)]
test_processed = data[len(y):]

# %%
#train test split for validation 
from sklearn.model_selection import train_test_split
X_train , X_val , y_train , y_val = train_test_split(
    train_processed , y , test_size = 0.2 , random_state = 42 )

# %%
# train model

from sklearn.ensemble import RandomForestRegressor 
model  = RandomForestRegressor(
     n_estimators = 200 , 
     max_depth = 15 , 
     min_samples_split = 5 , 
     random_state = 42 )
model.fit(X_train , y_train)
# Out:
# RandomForestRegressor(max_depth=15, min_samples_split=5, n_estimators=200,
#                       random_state=42)

# %%
# evaluate model 

from sklearn.metrics import r2_score , mean_squared_error
y_pred = model.predict(X_val)
r2 = r2_score(y_val , y_pred)
rmse = np.sqrt(mean_squared_error(y_val , y_pred))
print('R2 :' , r2)
print('RMSE :' , rmse)
# Out:
# R2 : 0.8838657922384376
# RMSE : 0.14721385573168408

# %%
#feature importance 
# improve model 
import pandas as pd 
importance = model.feature_importances_
imp_df = pd.DataFrame({
    'Feature' : train_processed.columns, 
    'Importance': importance}).sort_values(by='Importance' , ascending=False)
print(imp_df.head(15))
# Out:
#           Feature  Importance
# 3     OverallQual    0.551269
# 13      GrLivArea    0.116692
# 9     TotalBsmtSF    0.044309
# 22     GarageCars    0.041628
# 23     GarageArea    0.025646
# 6      BsmtFinSF1    0.022602
# 10       1stFlrSF    0.019362
# 188  CentralAir_Y    0.016115
# 33       HouseAge    0.015452
# 2         LotArea    0.014807
# 4     OverallCond    0.009842
# 34       RemodAge    0.009477
# 11       2ndFlrSF    0.007039
# 25    OpenPorchSF    0.006344
# 1     LotFrontage    0.005997

# %%
#cross validation 
from sklearn.model_selection import cross_val_score
scores = cross_val_score(
    model , train_processed , y , cv = 5 , scoring = 'r2')
print(scores.mean())
# Out:
# 0.8690803363022862

# %%
# train on full data 
model.fit(train_processed , y)
# Out:
# RandomForestRegressor(max_depth=15, min_samples_split=5, n_estimators=200,
#                       random_state=42)

# %%
# test 
test_predictions = np.expm1(model.predict(test_processed))

# %%
# create a submission file

# %%
submission  = pd.DataFrame({
    'Id' : test['Id'] , 
    'SalePrice' : test_predictions
})
submission.to_csv('submission1.csv' , index = False )

# %%
# save model 
import pickle 
pickle.dump(model , open('house_model.pkl' , 'wb'))

# %%
#write prediction script
import pickle
import numpy as np
model = pickle.load(open('house_model.pkl' , 'rb'))
def predict_price(data):
    return model.predict([data])[0]
